# %%
# !pip install googletrans==4.0.0-rc1
# !pip install textblob
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.11.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.1 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 7.0 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.8 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.4 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.4 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.11.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.9 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.9 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=9a95933e2a0371b7b1e22e865dabdaba7bf8cc7cf40ff32c0a4475e552248df4
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.6
#     Uninstalling httpcore-1.0.6:
#       Successfully uninstalled httpcore-1.0.6
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langsmith 0.1.142 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# openai 1.54.3 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.6)

# %%
from googletrans import Translator
from textblob import TextBlob

translator = Translator()

conversation = [
    ("RA", "नमस्ते श्री कुमार, मैं एक्स वाई जेड फाइनेंस से बोल रहा हूं। आपके लोन के बारे में बात करनी थी।"),
    ("B", "हां, बोलिए। क्या बात है?"),
    ("RA", "सर, आपका पिछले महीने का EMI अभी तक नहीं आया है। क्या कोई समस्या है?"),
    ("B", "हां, थोड़ी दिक्कत है। मेरी नौकरी चली गई है और मैं नया काम ढूंढ रहा हूं।"),
    ("RA", "ओह, यह तो बुरा हुआ। लेकिन सर, आपको समझना होगा कि लोन का भुगतान समय पर करना बहुत जरूरी है।"),
    ("B", "मैं समझता हूं, लेकिन अभी मेरे पास पैसे नहीं हैं। क्या कुछ समय मिल सकता है?"),
    ("RA", "हम समझते हैं आपकी स्थिति। क्या आप अगले हफ्ते तक कुछ भुगतान कर सकते हैं?"),
    ("B", "मैं कोशिश करूंगा, लेकिन पूरा EMI नहीं दे पाऊंगा। क्या आधा भुगतान चलेगा?"),
    ("RA", "ठीक है, आधा भुगतान अगले हफ्ते तक कर दीजिए। बाकी का क्या प्लान है आपका?"),
    ("B", "मुझे उम्मीद है कि अगले महीने तक मुझे नया काम मिल जाएगा। तब मैं बाकी बकाया चुका दूंगा।"),
    ("RA", "ठीक है। तो हम ऐसा करते हैं- आप अगले हफ्ते तक आधा EMI जमा कर दीजिए, और अगले महीने के 15 तारीख तक बाकी का भुगतान कर दीजिए। क्या यह आपको स्वीकार है?"),
    ("B", "हां, यह ठीक रहेगा। मैं इस प्लान का पालन करने की पूरी कोशिश करूंगा।"),
    ("RA", "बहुत अच्छा। मैं आपको एक SMS भेज रहा हूं जिसमें भुगतान की डिटेल्स होंगी। कृपया इसका पालन करें और समय पर भुगतान करें।"),
    ("B", "ठीक है, धन्यवाद आपके समझने के लिए।"),
    ("RA", "आपका स्वागत है। अगर कोई और सवाल हो तो मुझे बताइएगा। अलविदा।"),
    ("B", "अलविदा।")
]

borrower_sentences = [sentence for speaker, sentence in conversation if speaker == "B"]
agent_sentences = [sentence for speaker, sentence in conversation if speaker == "RA"]

def sentiment_report(sentences, speaker):
    print(f"\n--- Sentiment Analysis Report for {speaker} ---\n")
    for sentence in sentences:
        translated = translator.translate(sentence, src='hi', dest='en')
        english_text = translated.text

        analysis = TextBlob(english_text)
        sentiment = analysis.sentiment

        print(f"Original (Hindi): {sentence}")
        print(f"Translated (English): {english_text}")
        print(f"Sentiment: Polarity = {sentiment.polarity}, Subjectivity = {sentiment.subjectivity}")
        print("------")

sentiment_report(borrower_sentences, "Borrower")
sentiment_report(agent_sentences, "Recovery Agent")
# Out:
# --- Sentiment Analysis Report for Borrower ---
#
# Original (Hindi): हां, बोलिए। क्या बात है?
# Translated (English): Yes, speak.What is the matter?
# Sentiment: Polarity = 0.0, Subjectivity = 0.0
# ------
# Original (Hindi): हां, थोड़ी दिक्कत है। मेरी नौकरी चली गई है और मैं नया काम ढूंढ रहा हूं।
# Translated (English): Yes, there is some problem.My job is gone and I am looking for new work.
# Sentiment: Polarity = 0.13636363636363635, Subjectivity = 0.45454545454545453
# ------
# Original (Hindi): मैं समझता हूं, लेकिन अभी मेरे पास पैसे नहीं हैं। क्या कुछ समय मिल सकता है?
# Translated (English): I understand, but I don't have money right now.Can you get some time?
# Sentiment: Polarity = 0.2857142857142857, Subjectivity = 0.5357142857142857
# ------
# Original (Hindi): मैं कोशिश करूंगा, लेकिन पूरा EMI नहीं दे पाऊंगा। क्या आधा भुगतान चलेगा?
# Translated (English): I will try, but I will not be able to give full EMI.Will half the payment run?
# Sentiment: Polarity = 0.22777777777777777, Subjectivity = 0.44722222222222224
# ------
# Original (Hindi): मुझे उम्मीद है कि अगले महीने तक मुझे नया काम मिल जाएगा। तब मैं बाकी बकाया चुका दूंगा।
# Translated (English): I hope that I will get a new job by next month.Then I will pay the rest of the arrears.
# Sentiment: Polarity = 0.06818181818181818, Subjectivity = 0.22727272727272727
# ------
# Original (Hindi): हां, यह ठीक रहेगा। मैं इस प्लान का पालन करने की पूरी कोशिश करूंगा।
# Translated (English): Yes, it will be fine.I will try my best to follow this plan.
# Sentiment: Polarity = 1.0, Subjectivity = 0.3
# ------
# Original (Hindi): ठीक है, धन्यवाद आपके समझने के लिए।
# Translated (English): Okay, thanks for your understanding.
# Sentiment: Polarity = 0.35, Subjectivity = 0.35
# ------
# Original (Hindi): अलविदा।
# Translated (English): goodbye.
# Sentiment: Polarity = 0.0, Subjectivity = 0.0
# ------
#
# --- Sentiment Analysis Report for Recovery Agent ---
#
# Original (Hindi): नमस्ते श्री कुमार, मैं एक्स वाई जेड फाइनेंस से बोल रहा हूं। आपके लोन के बारे में बात करनी थी।
# Translated (English): Namaste Shri Kumar, I am speaking from X Y Z Finance.Had to talk about your loan.
# Sentiment: Polarity = 0.0, Subjectivity = 0.0
# ------
# Original (Hindi): सर, आपका पिछले महीने का EMI अभी तक नहीं आया है। क्या कोई समस्या है?
# Translated (English): Sir, your EMI of your previous month has not come yet.are there any problems?
# Sentiment: Polarity = -0.16666666666666666, Subjectivity = 0.16666666666666666
# ------
# Original (Hindi): ओह, यह तो बुरा हुआ। लेकिन सर, आपको समझना होगा कि लोन का भुगतान समय पर करना बहुत जरूरी है।
# Translated (English): Oh, it was bad.But Sir, you have to understand that it is very important to pay the loan on time.
# Sentiment: Polarity = 0.52, Subjectivity = 1.0
# ------
# Original (Hindi): हम समझते हैं आपकी स्थिति। क्या आप अगले हफ्ते तक कुछ भुगतान कर सकते हैं?
# Translated (English): We understand your situation.Can you pay something until next week?
# Sentiment: Polarity = 0.0, Subjectivity = 0.0
# ------
# Original (Hindi): ठीक है, आधा भुगतान अगले हफ्ते तक कर दीजिए। बाकी का क्या प्लान है आपका?
# Translated (English): Okay, pay half the payment by next week.What is your plan for the rest?
# Sentiment: Polarity = 0.11111111111111112, Subjectivity = 0.2222222222222222
# ------
# Original (Hindi): ठीक है। तो हम ऐसा करते हैं- आप अगले हफ्ते तक आधा EMI जमा कर दीजिए, और अगले महीने के 15 तारीख तक बाकी का भुगतान कर दीजिए। क्या यह आपको स्वीकार है?
# Translated (English): Ok.So we do this- you submit half EMI by next week, and pay the rest by the 15th of next month.Do you accept this?
# Sentiment: Polarity = -0.05555555555555555, Subjectivity = 0.05555555555555555
# ------
# Original (Hindi): बहुत अच्छा। मैं आपको एक SMS भेज रहा हूं जिसमें भुगतान की डिटेल्स होंगी। कृपया इसका पालन करें और समय पर भुगतान करें।
# Translated (English): Very good.I am sending you an SMS that will have payment details.Please follow it and pay on time.
# Sentiment: Polarity = 0.2, Subjectivity = 0.3
# ------
# Original (Hindi): आपका स्वागत है। अगर कोई और सवाल हो तो मुझे बताइएगा। अलविदा।
# Translated (English): you are welcome.If there is any other question, it will be told to me.goodbye.
# Sentiment: Polarity = -0.125, Subjectivity = 0.375
# ------
